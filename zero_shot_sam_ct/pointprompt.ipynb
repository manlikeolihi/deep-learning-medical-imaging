# %%
# Core imports
import numpy as np
import matplotlib.pyplot as plt
import cv2
import nibabel as nib

# SAM model imports
from segment_anything import sam_model_registry, SamPredictor

# %%
# !pip install nibabel opencv-python matplotlib
# Out:
# Requirement already satisfied: nibabel in ./opt/anaconda3/lib/python3.9/site-packages (5.3.2)
# Requirement already satisfied: opencv-python in ./opt/anaconda3/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in ./opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.22 in ./opt/anaconda3/lib/python3.9/site-packages (from nibabel) (1.22.0)
# Requirement already satisfied: packaging>=20 in ./opt/anaconda3/lib/python3.9/site-packages (from nibabel) (21.0)
# Requirement already satisfied: importlib-resources>=5.12 in ./opt/anaconda3/lib/python3.9/site-packages (from nibabel) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in ./opt/anaconda3/lib/python3.9/site-packages (from nibabel) (4.13.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=5.12->nibabel) (3.6.0)

# %%
import nibabel as nib
import cv2
import numpy as np
import matplotlib.pyplot as plt

from segment_anything import sam_model_registry, SamPredictor

# === Load image (CT slice) ===
image_path = "/Users/olihiidikwu/Downloads/Task07_Pancreas/imagesTr/pancreas_005.nii.gz"
img_data = nib.load(image_path).get_fdata()

slice_index = 55
image_slice = img_data[:, :, slice_index]

# Normalize + convert to RGB
image_norm = ((image_slice - np.min(image_slice)) / (np.max(image_slice) - np.min(image_slice)) * 255).astype(np.uint8)
image_rgb = cv2.cvtColor(image_norm, cv2.COLOR_GRAY2RGB)

# === Load SAM model ===
sam_checkpoint = "/Users/olihiidikwu/Downloads/sam_vit_b_01ec64.pth"  # Update if different
model_type = "vit_b"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
predictor = SamPredictor(sam)
predictor.set_image(image_rgb)

# === Apply Point Prompt ===
input_point = np.array([[180, 150]])  # Adjust coordinates as needed
input_label = np.array([1])  # 1 = foreground

masks, scores, logits = predictor.predict(
    point_coords=input_point,
    point_labels=input_label,
    multimask_output=False
)

# === Visualize ===
plt.figure(figsize=(6, 6))
plt.imshow(image_rgb)
plt.imshow(masks[0], alpha=0.5, cmap='Reds')
plt.title("SAM Output – Point Prompt")
plt.axis('off')
plt.show()

# === Save Output ===
cv2.imwrite("point.png", (masks[0] * 255).astype(np.uint8))
# Out:
# True
